# %%
# Angular projection of LRG data catalogue.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('enrique')

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()

data = np.genfromtxt('/Users/epaillas/data/eboss_v5/galaxy_cats/eBOSS_LRG_clustering_SGC_v5.dat.ang.txt')
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)
ax.set_xlabel('ra [rad]')
ax.set_ylabel('dec [rad]')
plt.show()

# %%
# Angular projection of LRG random catalogue.
# Second plot is just a zoom-in. 

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('enrique')

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.ran.ang.npy')
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)
ax.set_xlabel('ra [rad]')
ax.set_ylabel('dec [rad]')
plt.show()

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)
ax.set_xlabel('ra [rad]')
ax.set_ylabel('dec [rad]')
ax.set_xlim(2.2,2.7)
ax.set_ylim(0.6,0.9)
plt.show()

# %%
# Projections of the LRG data catalogue in cartesian
# coordinates along different axes.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('enrique')

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.dat.car.npy')

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)
ax.set_xlabel('x [Mpc]')
ax.set_ylabel('y [Mpc]')
plt.show()


fig = plt.figure(figsize=(8,5))
ax = plt.subplot()
ax.scatter(data[:,0], data[:,2], s=1.0, linewidth=0)
ax.set_xlabel('x [Mpc]')
ax.set_ylabel('z [Mpc]')
plt.show()

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()
ax.scatter(data[:,1], data[:,2], s=1.0, linewidth=0)
ax.set_xlabel('y [Mpc]')
ax.set_ylabel('z [Mpc]')
plt.show()

# %%
# Guard particles placed on survey boundaries
# to avoid tesselation leaking.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('enrique')

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.angCap.ang.npy')
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)
ax.set_xlabel('ra [rad]')
ax.set_ylabel('dec [rad]')
plt.show()

# %%
# A thin slice of constant declination,
# showing LRG data catalogue in red
# and guard particles in grey.

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(projection='polar')

ax.set_thetamin(25)
ax.set_thetamax(165)
#ax.set_rmax(5000)
ax.set_ylim(2000,3500)
#ax.set_rticks([3000, 4000, 5000, 6000])
ax.set_xlabel('RA [°]', fontsize=12)
ax.set_ylabel(r'$\chi$ [Mpc]', fontsize=12, rotation=20)
ax.xaxis.set_label_coords(0.5, 0.83)
ax.yaxis.set_label_coords(0.8, 0.255)

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.redCap.ang.npy')
data = np.asarray([i for i in data if 0.58 < i[1] < 0.60])
ax.scatter(data[:,0], data[:,2], s=2.0, color='grey')

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.angCap.ang.npy')
data = np.asarray([i for i in data if 0.58 < i[1] < 0.60])
ax.scatter(data[:,0], data[:,2], s=2.0, color='grey')

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.dat.ang.npy')
data = np.asarray([i for i in data if 0.58 < i[1] < 0.60])
ax.scatter(data[:,0], data[:,2], s=2.0, color='red')

plt.tight_layout()
plt.savefig('/home/epaillasv/data/eboss_v5/fig/wedge_data+guards.png', format='png')
plt.show()

# %%
# Projections in cartesian coordinates
# along different axes. LRG data catalogue
# is shown in red, angular guard particles
# in orange, whereas low and high redshift
# guard particle caps are shown in green.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('enrique')

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.dat.car.npy')
data = np.asarray([i for i in data if 1500 < i[2] < 1700])
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.angCap.car.npy')
data = np.asarray([i for i in data if 1500 < i[2] < 1700])
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.redCap.car.npy')
data = np.asarray([i for i in data if 1500 < i[2] < 1700])
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)

ax.set_xlabel('x [Mpc]')
ax.set_ylabel('y [Mpc]')
plt.show()


fig = plt.figure(figsize=(8,5))
ax = plt.subplot()

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.dat.car.npy')
data = np.asarray([i for i in data if 1500 < i[1] < 1700])
ax.scatter(data[:,0], data[:,2], s=1.0, linewidth=0)

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.angCap.car.npy')
data = np.asarray([i for i in data if 1500 < i[1] < 1700])
ax.scatter(data[:,0], data[:,2], s=1.0, linewidth=0)

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.redCap.car.npy')
data = np.asarray([i for i in data if 1500 < i[1] < 1700])
ax.scatter(data[:,0], data[:,2], s=1.0, linewidth=0)

ax.set_xlabel('x [Mpc]')
ax.set_ylabel('z [Mpc]')
plt.show()


fig = plt.figure(figsize=(8,5))
ax = plt.subplot()

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.dat.car.npy')
data = np.asarray([i for i in data if 1500 < i[0] < 1700])
ax.scatter(data[:,1], data[:,2], s=1.0, linewidth=0)

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.angCap.car.npy')
data = np.asarray([i for i in data if 1500 < i[0] < 1700])
ax.scatter(data[:,1], data[:,2], s=1.0, linewidth=0)

data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.redCap.car.npy')
data = np.asarray([i for i in data if 1500 < i[0] < 1700])
ax.scatter(data[:,1], data[:,2], s=1.0, linewidth=0)

ax.set_xlabel('y [Mpc]')
ax.set_ylabel('z [Mpc]')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('enrique')


fig = plt.figure(figsize=(8,5))
ax = plt.subplot()
data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.dat+Cap.car.npy')
data = np.asarray([i for i in data if 1500 < i[2] < 1700])
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)
ax.set_xlabel('x [Mpc]')
ax.set_ylabel('y [Mpc]')
plt.show()

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()
data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.dat+Cap.car.npy')
data = np.asarray([i for i in data if 1500 < i[1] < 1700])
ax.scatter(data[:,0], data[:,2], s=1.0, linewidth=0)
ax.set_xlabel('x [Mpc]')
ax.set_ylabel('z [Mpc]')
plt.show()

fig = plt.figure(figsize=(8,5))
ax = plt.subplot()
data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
eBOSS_LRG_clustering_NGC_v5.dat+Cap.car.npy')
data = np.asarray([i for i in data if 1500 < i[0] < 1700])
ax.scatter(data[:,1], data[:,2], s=1.0, linewidth=0)
ax.set_xlabel('y [Mpc]')
ax.set_ylabel('z [Mpc]')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('enrique')


fig = plt.figure(figsize=(8,5))
ax = plt.subplot()
data = np.genfromtxt('/home/epaillasv/data/eboss_v5/void_cats/eBOSS_LRG_clustering_NGC_v5.cen.ang.txt2')
#data = np.asarray([i for i in data if 1500 < i[2] < 1700])
ax.scatter(data[:,0], data[:,1], s=1.0, linewidth=0)
ax.set_xlabel('ra [rad]')
ax.set_ylabel('dec [rad]')
plt.show()

# fig = plt.figure(figsize=(8,5))
# ax = plt.subplot()
# data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
# eBOSS_LRG_clustering_NGC_v5.dat+Cap.car.npy')
# data = np.asarray([i for i in data if 1500 < i[1] < 1700])
# ax.scatter(data[:,0], data[:,2], s=1.0, linewidth=0)
# ax.set_xlabel('x [Mpc]')
# ax.set_ylabel('z [Mpc]')
# plt.show()

# fig = plt.figure(figsize=(8,5))
# ax = plt.subplot()
# data = np.load('/home/epaillasv/data/eboss_v5/galaxy_cats/\
# eBOSS_LRG_clustering_NGC_v5.dat+Cap.car.npy')
# data = np.asarray([i for i in data if 1500 < i[0] < 1700])
# ax.scatter(data[:,1], data[:,2], s=1.0, linewidth=0)
# ax.set_xlabel('y [Mpc]')
# ax.set_ylabel('z [Mpc]')
# plt.show()
